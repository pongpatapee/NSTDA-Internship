# %%
import numpy as np
import pandas as pd

# %%
col_val = ['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8']
data = pd.read_csv('test.log')

# %%
data.head()
# Out:
#    2676  2668  2667  2741  2782  2707  2689  2669
# 0  2704  2668  2668  2842  2866  2716  2666  2668
# 1  2695  2668  2668  2826  2837  2720  2673  2668
# 2  2660  2668  2668  2747  2760  2709  2676  2668
# 3  2593  2668  2667  2725  2770  2706  2667  2669
# 4  2673  2668  2667  2741  2785  2694  2672  2668

# %%
data = np.genfromtxt('test.log', delimiter=',')

# %%
df = pd.DataFrame(data=data, columns=col_val)

# %%
df
# Out:
#         s1      s2      s3      s4      s5      s6      s7      s8
# 0   2676.0  2668.0  2667.0  2741.0  2782.0  2707.0  2689.0  2669.0
# 1   2704.0  2668.0  2668.0  2842.0  2866.0  2716.0  2666.0  2668.0
# 2   2695.0  2668.0  2668.0  2826.0  2837.0  2720.0  2673.0  2668.0
# 3   2660.0  2668.0  2668.0  2747.0  2760.0  2709.0  2676.0  2668.0
# 4   2593.0  2668.0  2667.0  2725.0  2770.0  2706.0  2667.0  2669.0
# ..     ...     ...     ...     ...     ...     ...     ...     ...
# 64  2663.0  2667.0  2667.0  2819.0  2852.0  2715.0  2673.0  2668.0
# 65  2671.0  2668.0  2665.0  2546.0  2547.0  2632.0  2682.0  2668.0
# 66  2482.0  2667.0  2666.0  2578.0  2589.0  2662.0  2682.0  2668.0
# 67  2731.0  2668.0  2670.0  2975.0  2834.0  2693.0  2676.0  2668.0
# 68  2677.0  2667.0  2669.0  2884.0  2925.0  2731.0  2683.0  2669.0
#
# [69 rows x 8 columns]

# %%
df.corr()
# Out:
#           s1        s2        s3        s4        s5        s6        s7  \
# s1  1.000000  0.292033  0.470681  0.693760  0.645878  0.517341  0.173928
# s2  0.292033  1.000000 -0.035696  0.037966 -0.024757 -0.117288  0.078990
# s3  0.470681 -0.035696  1.000000  0.878616  0.812331  0.683959  0.039720
# s4  0.693760  0.037966  0.878616  1.000000  0.958172  0.791562  0.028351
# s5  0.645878 -0.024757  0.812331  0.958172  1.000000  0.877049 -0.002504
# s6  0.517341 -0.117288  0.683959  0.791562  0.877049  1.000000 -0.043766
# s7  0.173928  0.078990  0.039720  0.028351 -0.002504 -0.043766  1.000000
# s8 -0.128225  0.170641 -0.039562 -0.051395 -0.041149  0.041220 -0.030581
#
#           s8
# s1 -0.128225
# s2  0.170641
# s3 -0.039562
# s4 -0.051395
# s5 -0.041149
# s6  0.041220
# s7 -0.030581
# s8  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
